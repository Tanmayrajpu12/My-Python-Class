# %%
import pandas as pd
import numpy as np

# %%
# unique value
# Describe
# value_count
# sample
# fillna
# drop
# info
# mean
# isna
# sum
# count
# sort_value
# head
# tail
# max
# min

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Downloads\Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Area_type of Value_counts
df['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
# price check
df['price'].value_counts()
# Out:
# price
# 75.00     310
# 65.00     302
# 55.00     275
# 60.00     270
# 45.00     240
#          ...
# 351.00      1
# 54.10       1
# 80.64       1
# 32.73       1
# 488.00      1
# Name: count, Length: 1994, dtype: int64

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
# Fillna society
df['society'].fillna('KnowName')
# Out:
# 0         Coomee
# 1         Theanmp
# 2        KnowName
# 3         Soiewre
# 4        KnowName
#            ...
# 13315     ArsiaEx
# 13316    KnowName
# 13317     Mahla T
# 13318     SollyCl
# 13319    KnowName
# Name: society, Length: 13320, dtype: object

# %%
# df of describe
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
# price in top 10 
df['price'].head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['balcony'].fillna(10).value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['area_type'] == 'Super built-up Area'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319    False
# Name: area_type, Length: 13320, dtype: bool

# %%
# df of count  
df.count()
# Out:
# area_type       13320
# availability    13320
# location        13319
# size            13304
# society          7818
# total_sqft      13320
# bath            13247
# balcony         12711
# price           13320
# dtype: int64

# %%
# df of value counts
df.value_counts()
# Out:
# area_type             availability   location                        size   society  total_sqft   bath  balcony  price
# Super built-up  Area  Ready To Move  Haralur Road                    2 BHK  RInceeg  1243         2.0   2.0      46.00     10
#                                      HSR Layout                      2 BHK  NRosete  1140         2.0   2.0      46.00      9
#                                      Parappana Agrahara              2 BHK  Peide L  1194         2.0   2.0      47.00      7
#                       21-Dec         Kanakpura Road                  3 BHK  PrarePa  1100         3.0   2.0      53.00      5
#                       Ready To Move  Raja Rajeshwari Nagar           2 BHK  GrrvaGr  1196         2.0   2.0      40.54      5
#                                                                                                                            ..
# ...

# %%
# df of check in 2BHK 
df[df['size'] == '2 BHK']
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5      Super built-up  Area  Ready To Move                Whitefield  2 BHK
# 12     Super built-up  Area  Ready To Move        7th Phase JP Nagar  2 BHK
# 13           Built-up  Area  Ready To Move                 Gottigere  2 BHK
# ...                     ...            ...                       ...    ...
# 13302  Super built-up  Area  Ready To Move      Annaiah Reddy Layout  2 BHK
# 13304  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
# 13310  Super built-up  Area  Ready To Move              Rachenahalli  2 BHK
# 13312  Super built-up  Area  Ready To Move                 Bellandur  2 BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
#
#        society total_sqft  bath  balcony  price
# ...

# %%
df.sample()
# Out:
#            area_type availability                            location   size  \
# 6376  Built-up  Area       21-Dec  Judicial Layout, Kanakapura Road,   3 BHK
#
#      society total_sqft  bath  balcony  price
# 6376     NaN       1300   3.0      2.0   64.0

# %%
# availability
df['availability'].value_counts()
# Out:
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64

# %%
df['location'].count()
# Out:
# 13319

# %%
# sort_value
df['location'].sort_values()
# Out:
# 2557                   Anekal
# 8385                Banaswadi
# 7638              Basavangudi
# 2486              Bhoganhalli
# 10745     Devarabeesana Halli
#                  ...
# 6881                 tc.palya
# 11013           vinayakanagar
# 3483     white field,kadugodi
# 4586               whitefiled
# 568                       NaN
# Name: location, Length: 13320, dtype: object

# %%
# df of size 

df[df['size'] == '4 Bedroom']
# Out:
#             area_type   availability               location       size  \
# 1          Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 11         Plot  Area  Ready To Move             Whitefield  4 Bedroom
# 22         Plot  Area  Ready To Move            Thanisandra  4 Bedroom
# 56     Built-up  Area         20-Feb            Devanahalli  4 Bedroom
# 62         Plot  Area  Ready To Move             Whitefield  4 Bedroom
# ...               ...            ...                    ...        ...
# 13213      Plot  Area  Ready To Move   Rajarajeshwari nagar  4 Bedroom
# 13246  Built-up  Area  Ready To Move         Sarjapur  Road  4 Bedroom
# 13247      Plot  Area  Ready To Move  5th Stage BEML Layout  4 Bedroom
# 13275      Plot  Area  Ready To Move              Kothannur  4 Bedroom
# 13306      Plot  Area  Ready To Move  Rajarajeshwari Nagara  4 Bedroom
#
#        society   total_sqft  bath  balcony  price
# 1      Theanmp         2600   5.0      3.0  120.0
# ...

# %%
df[df['size'] == '3 BHK']
# Out:
#                   area_type   availability            location   size  \
# 2            Built-up  Area  Ready To Move         Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move  Lingadheeranahalli  3 BHK
# 8      Super built-up  Area  Ready To Move        Marathahalli  3 BHK
# 10     Super built-up  Area         18-Feb          Whitefield  3 BHK
# 16     Super built-up  Area  Ready To Move       Bisuvanahalli  3 BHK
# ...                     ...            ...                 ...    ...
# 13307        Built-up  Area  Ready To Move        Billekahalli  3 BHK
# 13308        Built-up  Area  Ready To Move   Bannerghatta Road  3 BHK
# 13309  Super built-up  Area  Ready To Move        Yeshwanthpur  3 BHK
# 13313  Super built-up  Area  Ready To Move         Uttarahalli  3 BHK
# 13314  Super built-up  Area  Ready To Move   Green Glen Layout  3 BHK
#
#        society total_sqft  bath  balcony   price
# 2          NaN       1440   2.0      3.0   62.00
# ...

# %%
# Name of size in top head Values
df['size'].head(10).value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['society'].value_counts().fillna(10)
# Out:
# society
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# Amionce     1
# JaghtDe     1
# Jauraht     1
# Brity U     1
# RSntsAp     1
# Name: count, Length: 2688, dtype: int64

# %%
# society fillna
df['society'].fillna('Know Name')
# Out:
# 0          Coomee
# 1          Theanmp
# 2        Know Name
# 3          Soiewre
# 4        Know Name
#            ...
# 13315      ArsiaEx
# 13316    Know Name
# 13317      Mahla T
# 13318      SollyCl
# 13319    Know Name
# Name: society, Length: 13320, dtype: object

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# total_sqft in top head top 10 value in tail top 10 value
df['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200    843
# 1100    221
# 1500    205
# 2400    196
# 600     180
#        ...
# 3580      1
# 2461      1
# 1437      1
# 2155      1
# 4689      1
# Name: count, Length: 2117, dtype: int64

# %%
df['total_sqft'].head(10)
# Out:
# 0    1056
# 1    2600
# 2    1440
# 3    1521
# 4    1200
# 5    1170
# 6    2732
# 7    3300
# 8    1310
# 9    1020
# Name: total_sqft, dtype: object

# %%
# total_sqft in 1000 values
df[df['total_sqft']=='1000']
# Out:
#                   area_type   availability            location       size  \
# 12     Super built-up  Area  Ready To Move  7th Phase JP Nagar      2 BHK
# 90           Built-up  Area  Ready To Move        Sanjay nagar      2 BHK
# 91     Super built-up  Area         18-Dec     Electronic City      2 BHK
# 143    Super built-up  Area  Ready To Move         ISRO Layout      2 BHK
# 331    Super built-up  Area         20-Mar      Sarjapur  Road      2 BHK
# ...                     ...            ...                 ...        ...
# 12869            Plot  Area  Ready To Move         Hegde Nagar  2 Bedroom
# 12950            Plot  Area  Ready To Move  5th Phase JP Nagar  4 Bedroom
# 13175  Super built-up  Area  Ready To Move  Yelahanka New Town      3 BHK
# 13193  Super built-up  Area  Ready To Move  Horamavu Banaswadi      2 BHK
# 13276  Super built-up  Area  Ready To Move    LB Shastri Nagar      2 BHK
#
#        society total_sqft  bath  balcony   price
# ...

# %%
df['total_sqft'].head(10)
# Out:
# 0    1056
# 1    2600
# 2    1440
# 3    1521
# 4    1200
# 5    1170
# 6    2732
# 7    3300
# 8    1310
# 9    1020
# Name: total_sqft, dtype: object

# %%
df['bath'].head().value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['bath'].mean()
# Out:
# 2.6926096474673513

# %%
df['bath'].describe()
# Out:
# count    13247.000000
# mean         2.692610
# std          1.341458
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         40.000000
# Name: bath, dtype: float64

# %%
df['price'].sum()
# Out:
# 1499374.145

# %%
df['price'].value_counts()
# Out:
# price
# 75.00     310
# 65.00     302
# 55.00     275
# 60.00     270
# 45.00     240
#          ...
# 351.00      1
# 54.10       1
# 80.64       1
# 32.73       1
# 488.00      1
# Name: count, Length: 1994, dtype: int64

# %%
df['price'].describe()
# Out:
# count    13320.000000
# mean       112.565627
# std        148.971674
# min          8.000000
# 25%         50.000000
# 50%         72.000000
# 75%        120.000000
# max       3600.000000
# Name: price, dtype: float64

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df['bath'].count()
# Out:
# 13247

# %%
df.describe().sum()
# Out:
# bath       13299.034068
# balcony    12721.401639
# price      17431.537300
# dtype: float64

# %%
df['bath'].max()
# Out:
# 40.0

# %%
df['bath'].min()
# Out:
# 1.0

# %%
df['balcony'].max()
# Out:
# 3.0

# %%
df['price'].max()
# Out:
# 3600.0

# %%
df['price'].min()
# Out:
# 8.0

# %%
df['society'],np.nan
# Out:
# (0        Coomee
#  1        Theanmp
#  2            NaN
#  3        Soiewre
#  4            NaN
#            ...
#  13315    ArsiaEx
#  13316        NaN
#  13317    Mahla T
#  13318    SollyCl
#  13319        NaN
#  Name: society, Length: 13320, dtype: object,
#  nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
pd.DataFrame(df)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# unique value
# Describe
# value_count
# sample
# fillna
# drop
# info
# mean
# isna
# sum
# count
# sort_value
# head
# tail
# max
# min
